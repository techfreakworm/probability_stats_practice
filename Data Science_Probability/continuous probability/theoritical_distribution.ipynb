# %% [markdown]
# ## Using pnorm() to calculate probabilities
# We say that a random quantity is normally distributed with average `avg` and standard deviation `s`, if its probabilit is defined by: <br>
# F(a) = pnorm(a, avg, s)

# %%
library(tidyverse)
library(dslabs)
data(heights)
x <- heights %>% filter(sex=="Male") %>% pull(height)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.0
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
pnorm(70.5, mean(x), sd(x)) #Probability that a Male is <= 70.5
# Out:
# [1] 0.628631

# %%
1 - pnorm(70.5, mean(x), sd(x)) #Probability that a Male is > 70.5
# Out:
# [1] 0.371369

# %% [markdown]
# ## Discretization and the normal approximation

# %%
# plot distribution of exact heights in data
plot(prop.table(table(x)), xlab = "a = Height in inches", ylab = "Pr(x = a)")
# Out:
# plot without title

# %%
# probabilities in actual data over length 1 ranges containing an integer
mean(x <= 68.5) - mean(x <= 67.5)
mean(x <= 69.5) - mean(x <= 68.5)
mean(x <= 70.5) - mean(x <= 69.5)
# Out:
# [1] 0.114532
# [1] 0.1194581
# [1] 0.1219212

# %%
# probabilities in normal approximation match well
pnorm(68.5, mean(x), sd(x)) - pnorm(67.5, mean(x), sd(x))
pnorm(69.5, mean(x), sd(x)) - pnorm(68.5, mean(x), sd(x))
pnorm(70.5, mean(x), sd(x)) - pnorm(69.5, mean(x), sd(x))
# Out:
# [1] 0.1031077
# [1] 0.1097121
# [1] 0.1081743

# %%
# probabilities in actual data over other ranges don't match normal approx as well
mean(x <= 70.9) - mean(x <= 70.1)
pnorm(70.9, mean(x), sd(x)) - pnorm(70.1, mean(x), sd(x))
# Out:
# [1] 0.02216749
# [1] 0.08359562

# %% [markdown]
# Explaination: In the ranges 68.5 to 70.5, they are rounded off (discretized) that's why the normal approximation is better. But in range 70.1 to 70.9, they are actual continuous ranges means that they're not rounded off (not discretized) that's why normal approximation is not good.
