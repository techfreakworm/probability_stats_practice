# %% [markdown]
# NOTE: for continous variables, probability for a single value is not defined

# %% [markdown]
# ## Probability density comes to save

# %% [markdown]
# $$F(a) = \mbox{Pr}(X \leq a) = \int_{-\infty}^a f(x) dx$$

# %% [markdown]
# For example, to use the normal approximation to estimate the probability of someone being taller than 76 inches, we can use the probability density

# %%
library(tidyverse)
library(dslabs)
data(heights)
x <- heights %>% filter(sex=="Male") %>% pull(height)

# %%
avg <- mean(x)
s <- sd(x)
1 - pnorm(76, avg, s)
# Out:
# [1] 0.03206008

# %% [markdown]
# NOTE: We can get the probability density function for the normal distribution using the function `dnorm`

# %%
plot(x)
# Out:
# plot without title

# %%
data.frame(x, f = dnorm(x)) %>%
    ggplot(aes(x, f)) +
    geom_line()
# Out:
# plot without title

# %% [markdown]
# ## Plotting the probability density for the normal distribution

# %%
library(tidyverse)
x <- seq(-4, 4, length = 100)
data.frame(x, f = dnorm(x)) %>%
    ggplot(aes(x, f)) +
    geom_line()
# Out:
# plot without title
