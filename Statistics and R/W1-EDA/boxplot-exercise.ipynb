# %%
head(InsectSprays)
# Out:
#   count spray
# 1 10    A
# 2  7    A
# 3 20    A
# 4 14    A
# 5 14    A
# 6 12    A

# %%
boxplot(split(InsectSprays$count, InsectSprays$spray))
# Out:
# plot without title

# %%
boxplot(InsectSprays$count ~ InsectSprays$spray)
# Out:
# plot without title

# %%
library(dplyr)

# %%
data(nym.2002, package="UsingR")

# %%
dat = nym.2002

# %%
head(dat)
# Out:
#       place gender age home time
# 3475   3592 Male   52  GBR  217.4833
# 13594 13853 Female 40  NY   272.5500
# 12012 12256 Male   31  FRA  265.2833
# 10236 10457 Female 33  MI   256.1500
# 9476   9686 Male   33  NY   252.2500
# 1720   1784 Male   40  NJ   201.9667

# %%
male_dat <- filter(dat, gender=="Male")

# %%
female_dat <- filter(dat, gender=="Female")

# %%
hist(male_dat$time)
# Out:
# Plot with title “Histogram of male_dat$time”

# %%
hist(female_dat$time)
# Out:
# Plot with title “Histogram of female_dat$time”

# %%
qqnorm(male_dat$time)
qqline(male_dat$time)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
qqnorm(female_dat$time)
qqline(female_dat$time)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
boxplot(dat$time ~ dat$gender)
# Out:
# plot without title

# %%
mean(female_dat$time)
# Out:
# [1] 284.9366

# %%
mean(male_dat$time)
# Out:
# [1] 261.8209

# %%
median(female_dat$time)
# Out:
# [1] 277.725

# %%
median(male_dat$time)
# Out:
# [1] 256.0167
