# %%
library(UsingR)
# Out:
# Loading required package: MASS
#
# Loading required package: HistData
#
# Loading required package: Hmisc
#
# Loading required package: lattice
#
# Loading required package: survival
#
# Loading required package: Formula
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
#
#
#
# Attaching package: ‘UsingR’
#
#
# The following object is masked from ‘package:survival’:
#
#     cancer

# %%
father.son
# Out:
#      fheight  sheight
# 1    65.04851 59.77827
# 2    63.25094 63.21404
# 3    64.95532 63.34242
# 4    65.75250 62.79238
# 5    61.13723 64.28113
# 6    63.02254 64.24221
# 7    65.37053 64.08231
# 8    64.72398 63.99574
# 9    66.06509 64.61338
# 10   66.96738 63.97944
# 11   59.00800 65.24451
# 12   62.93203 65.35102
# 13   63.67063 65.67992
# 14   64.07386 65.43664
# 15   64.68851 65.29391
# 16   65.15466 64.79017
# 17   66.37353 65.01881
# 18   65.57704 65.54640
# 19   67.36765 65.08145
# 20   66.75929 65.49008
# 21   67.79764 65.13520
# 22   69.53480 65.51262
# 23   62.54014 66.58436
# 24   63.81016 66.37842
# 25   64.45650 66.14782
# 26   64.96650 65.97259
# 27   64.70662 65.95887
# 28   65.73829 66.45202
# 29   65.50141 65.74797
# 30   65.55416 65.97164
# ⋮    ⋮        ⋮
# 1049 70.70290 72.07098
# 1050 72.35959 72.30647
# 1051 72.36610 72.05185
# 1052 67.17534 72.75204
# 1053 67.84045 72.79178
# 1054 68.90530 73.50606
# 1055 70.37520 73.68578
# 1056 71.18523 72.79593
# 1057 71.41254 73.41049
# 1058 71.70673 73.02077
# 1059 72.60072 73.20758
# 1060 67.57652 74.49237
# 1061 68.55814 73.81263
# 1062 70.95019 73.81376
# 1063 71.99783 73.82642
# 1064 75.17469 73.81739
# 1065 73.07157 75.57544
# 1066 69.92407 77.23474
# 1067 65.54323 60.05859
# 1068 72.56261 76.81927
# 1069 72.15051 66.72684
# 1070 63.22006 58.79456
# 1071 73.26450 67.89277
# 1072 65.81296 61.04946
# 1073 67.70657 59.81693
# 1074 66.99681 70.75232
# 1075 71.33181 68.26774
# 1076 71.78314 69.30589
# 1077 70.73837 69.30199
# 1078 70.30609 67.01500

# %%
x <-father.son$fheight

# %%
round(sample(x, 20), 1)
# Out:
#  [1] 72.4 64.3 68.5 66.0 71.5 70.9 63.9 64.6 69.8 66.1 71.8 70.2 67.6 66.5 71.2
# [16] 69.9 69.3 67.9 72.3 65.3

# %%
length(x)
# Out:
# [1] 1078

# %%
hist(x, breaks=seq(floor(min(x)), ceiling(max(x))),
        main="Height Histogram", xlab="Height in inches")
# Out:
# Plot with title “Height Histogram”

# %%
xs <- seq(floor(min(x)), ceiling(max(x)), 0.1)
plot(xs, ecdf(x)(xs), type="l",
        xlab="Height in inches", ylab="F(x)")
# Out:
# plot without title

# %%
xs
# Out:
#   [1] 59.0 59.1 59.2 59.3 59.4 59.5 59.6 59.7 59.8 59.9 60.0 60.1 60.2 60.3 60.4
#  [16] 60.5 60.6 60.7 60.8 60.9 61.0 61.1 61.2 61.3 61.4 61.5 61.6 61.7 61.8 61.9
#  [31] 62.0 62.1 62.2 62.3 62.4 62.5 62.6 62.7 62.8 62.9 63.0 63.1 63.2 63.3 63.4
#  [46] 63.5 63.6 63.7 63.8 63.9 64.0 64.1 64.2 64.3 64.4 64.5 64.6 64.7 64.8 64.9
#  [61] 65.0 65.1 65.2 65.3 65.4 65.5 65.6 65.7 65.8 65.9 66.0 66.1 66.2 66.3 66.4
#  [76] 66.5 66.6 66.7 66.8 66.9 67.0 67.1 67.2 67.3 67.4 67.5 67.6 67.7 67.8 67.9
#  [91] 68.0 68.1 68.2 68.3 68.4 68.5 68.6 68.7 68.8 68.9 69.0 69.1 69.2 69.3 69.4
# [106] 69.5 69.6 69.7 69.8 69.9 70.0 70.1 70.2 70.3 70.4 70.5 70.6 70.7 70.8 70.9
# [121] 71.0 71.1 71.2 71.3 71.4 71.5 71.6 71.7 71.8 71.9 72.0 72.1 72.2 72.3 72.4
# [136] 72.5 72.6 72.7 72.8 72.9 73.0 73.1 73.2 73.3 73.4 73.5 73.6 73.7 73.8 73.9
# [151] 74.0 74.1 74.2 74.3 74.4 74.5 74.6 74.7 74.8 74.9 75.0 75.1 75.2 75.3 75.4
# [166] 75.5 75.6 75.7 75.8 75.9 76.0

# %%
ecdf(x)(74)
# 99.35% People are shorter than 74 inches
# Out:
# [1] 0.9935065

# %% [markdown]
# # QQ PLOT

# %%
xs <- seq(floor(min(x)), ceiling(max(x)), 0.1)
plot(xs, ecdf(x)(xs), type="l",
        xlab="Height in inches", ylab="F(x)")
# Out:
# plot without title

# %%
mean(x<69)
# Out:
# [1] 0.6716141

# %%
pnorm(69,mean(x), sd(x))
# Out:
# [1] 0.6837859

# %%
ps <- seq(0.01, 0.99, 0.01)

# %%
qs <- quantile(x, ps)

# %%
normalqs <- qnorm(ps, mean(x), sd(x))

# %%
plot(normalqs, qs, xlab="Normal percentiles",
    ylab="Height in Percentiles")
# Out:
# plot without title

# %%
mean(x>70)
# Out:
# [1] 0.2059369

# %%
1-pnorm(70,mean(x), sd(x))
# Out:
# [1] 0.1997182

# %%
ps <- seq(0.01, 0.99, 0.01)

# %%
qs <- quantile(x, ps)

# %%
normalqs <- qnorm(ps, mean(x), sd(x))

# %%
plot(normalqs, qs, xlab="Normal percentiles",
    ylab="Height in percentiles")
abline(0,1)
# Out:
# plot without title

# %%
qqnorm(x)
qqline(x)
# Out:
# Plot with title “Normal Q-Q Plot”
