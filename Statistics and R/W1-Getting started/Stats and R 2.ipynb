# %% [markdown]
# # My script

# %%
x <- 1:10

# %%
y<-rnorm(10)

# %%
plot(x,y)
# Out:
# plot without title

# %%
fit <- lm(y ~ x)

# %%
fit
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#     0.44352     -0.08679
