# %%
x <- unlist(read.csv("../dagdata/inst/extdata/femaleControlsPopulation.csv"))

# %%
set.seed(1)

# %%
n <- 1000

# %%
averages5 <- vector("numeric", n)
for(i in 1:n) {
    X <- sample(x, 5)
    averages5[i] <- mean(X)
}

# %%
averages50 <- vector("numeric", n)
for(i in 1:n) {
    X <- sample(x, 50)
    averages50[i] <- mean(X)
}

# %%
hist(averages5)
# Out:
# Plot with title “Histogram of averages5”

# %%
hist(averages50)
# Out:
# Plot with title “Histogram of averages50”

# %%
ecdf(averages50)(23) - ecdf(averages50)(25)
# Out:
# [1] -0.978

# %% [markdown]
# ## Note that you can use the function `pnorm()` to find the proportion of observations below a cutoff `x` given a normal distribution with mean `mu` and standard deviation `sigma` with `pnorm(x, mu, sigma)` or `pnorm( (x-mu)/sigma )`.

# %%
pnorm(23, 23.9, 0.43) - pnorm(25, 23.9, 0.43)
# Out:
# [1] -0.9765648
